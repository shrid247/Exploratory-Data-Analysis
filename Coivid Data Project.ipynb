# %% [markdown]
# # Contnet
# The dataset was provided by the Mexican government (link). This dataset contains an enormous number of anonymized patient-related information including pre-conditions. The raw dataset consists of 21 unique features and 1,048,576 unique patients. In the Boolean features, 1 means "yes" and 2 means "no". values as 97 and 99 are missing data.
#
# sex: 1 for female and 2 for male.
# age: of the patient.
# classification: covid test findings. Values 1-3 mean that the patient was diagnosed with covid in different
# degrees. 4 or higher means that the patient is not a carrier of covid or that the test is inconclusive.
# patient type: type of care the patient received in the unit. 1 for returned home and 2 for hospitalization.
# pneumonia: whether the patient already have air sacs inflammation or not.
# pregnancy: whether the patient is pregnant or not.
# diabetes: whether the patient has diabetes or not.
# copd: Indicates whether the patient has Chronic obstructive pulmonary disease or not.
# asthma: whether the patient has asthma or not.
# inmsupr: whether the patient is immunosuppressed or not.
# hypertension: whether the patient has hypertension or not.
# cardiovascular: whether the patient has heart or blood vessels related disease.
# renal chronic: whether the patient has chronic renal disease or not.
# other disease: whether the patient has other disease or not.
# obesity: whether the patient is obese or not.
# tobacco: whether the patient is a tobacco user.
# usmr: Indicates whether the patient treated medical units of the first, second or third level.
# medical unit: type of institution of the National Health System that provided the care.
# intubed: whether the patient was connected to the ventilator.
# icu: Indicates whether the patient had been admitted to an Intensive Care Unit.
# date died: If the patient died indicate the date of death, and 9999-99-99 otherwise.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\shrid\Downloads\Covid data\Covid Data.csv")

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %% [markdown]
# 1.What is the average age of the patients?

# %%
df['AGE'].mean()
# Out:
# 41.794102472403026

# %% [markdown]
# 2. What is the maximum and minimum age in the dataset?

# %%
df.nunique()
# Out:
# USMER                     2
# MEDICAL_UNIT             13
# SEX                       2
# PATIENT_TYPE              2
# DATE_DIED               400
# INTUBED                   4
# PNEUMONIA                 3
# AGE                     121
# PREGNANT                  4
# DIABETES                  3
# COPD                      3
# ASTHMA                    3
# INMSUPR                   3
# HIPERTENSION              3
# OTHER_DISEASE             3
# CARDIOVASCULAR            3
# OBESITY                   3
# RENAL_CHRONIC             3
# TOBACCO                   3
# CLASIFFICATION_FINAL      7
# ICU                       4
# dtype: int64

# %%
df.agg({'AGE':['max','min']})
# Out:
#      AGE
# max  121
# min    0

# %% [markdown]
# 3. How many unique patients are there in the dataset?

# %%
a=df.stack().unique()

# %%
a.head()
# Out:
# 97    848544
# 2     159050
# 1      33656
# 99      7325
# Name: INTUBED, dtype: int64

# %%
len(a)
# Out:
# 522

# %% [markdown]
# 4.What is the distribution of patient types (returned home vs. hospitalized)?

# %%
df['PATIENT_TYPE'].value_counts()
# Out:
# 1    848544
# 2    200031
# Name: PATIENT_TYPE, dtype: int64

# %%
sns.countplot(x=df['PATIENT_TYPE'])
plt.title('Patient Returned home vs Hosptitalized')
# Out:
# Text(0.5, 1.0, 'Patient Returned home vs Hosptitalized')

# %% [markdown]
# 5.What are the top three pre-existing conditions among the patients?

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
df.isna().sum()# the null value in this data are filled as 97 or 99
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
#df[df.columns[9:19]]
selected_column= df.iloc[:,list(range(9,19))+[6]]
selected_column.head()
# Out:
#    DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2     2       2        2             1              2
# 1         2     2       2        2             1              2
# 2         1     2       2        2             2              2
# 3         2     2       2        2             2              2
# 4         1     2       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  PNEUMONIA
# 0               2        2              2        2          1
# 1               2        1              1        2          1
# 2               2        2              2        2          2
# 3               2        2              2        2          2
# 4               2        2              2        2          2

# %%
d=selected_column.eq(1)

# %%
disease_count=d.sum()

# %%
disease_count.nlargest(3)
# Out:
# HIPERTENSION    162729
# OBESITY         159816
# PNEUMONIA       140038
# dtype: int64

# %% [markdown]
# 6. How many patients have missing values for the "INTUBED" column?

# %%
df.head(2)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
#
# [2 rows x 21 columns]

# %%
a=df['INTUBED'].value_counts()
count_of_values = a.get(97, 0) + a.get(99, 0)
print(f'count of null_values is {count_of_values}')
# Out:
# count of null_values is 855869

# %% [markdown]
# 7. Can we visualize the correlation between different pre-existing conditions using a heatmap?

# %%
selected_column.corr()
# Out:
#                 DIABETES      COPD    ASTHMA   INMSUPR  HIPERTENSION  \
# DIABETES        1.000000  0.828823  0.829349  0.781108      0.835018
# COPD            0.828823  1.000000  0.908929  0.852273      0.855249
# ASTHMA          0.829349  0.908929  1.000000  0.868917      0.864264
# INMSUPR         0.781108  0.852273  0.868917  1.000000      0.825158
# HIPERTENSION    0.835018  0.855249  0.864264  0.825158      1.000000
# OTHER_DISEASE   0.634611  0.687323  0.696709  0.734826      0.671532
# CARDIOVASCULAR  0.809417  0.880097  0.891026  0.853365      0.861063
# OBESITY         0.752739  0.814868  0.824631  0.783953      0.805127
# RENAL_CHRONIC   0.812657  0.884032  0.895050  0.852755      0.860477
# TOBACCO         0.771763  0.836097  0.845067  0.806749      0.816539
# PNEUMONIA      -0.004484 -0.005618 -0.005392 -0.000802     -0.004799
#
#                 OTHER_DISEASE  CARDIOVASCULAR   OBESITY  RENAL_CHRONIC  \
# ...

# %%
sns.heatmap(selected_column.corr(),annot=True,fmt='.1f')
# Out:
# <Axes: >

# %% [markdown]
# 8. How does age correlate with the different COVID test findings ?

# %%
s= df.iloc[:,list(range(9,19))+[6]+[7]]
s.head()
# Out:
#    DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2     2       2        2             1              2
# 1         2     2       2        2             1              2
# 2         1     2       2        2             2              2
# 3         2     2       2        2             2              2
# 4         1     2       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  PNEUMONIA  AGE
# 0               2        2              2        2          1   65
# 1               2        1              1        2          1   72
# 2               2        2              2        2          2   55
# 3               2        2              2        2          2   53
# 4               2        2              2        2          2   68

# %%
s.corr()
# Out:
#                 DIABETES      COPD    ASTHMA   INMSUPR  HIPERTENSION  \
# DIABETES        1.000000  0.828823  0.829349  0.781108      0.835018
# COPD            0.828823  1.000000  0.908929  0.852273      0.855249
# ASTHMA          0.829349  0.908929  1.000000  0.868917      0.864264
# INMSUPR         0.781108  0.852273  0.868917  1.000000      0.825158
# HIPERTENSION    0.835018  0.855249  0.864264  0.825158      1.000000
# OTHER_DISEASE   0.634611  0.687323  0.696709  0.734826      0.671532
# CARDIOVASCULAR  0.809417  0.880097  0.891026  0.853365      0.861063
# OBESITY         0.752739  0.814868  0.824631  0.783953      0.805127
# RENAL_CHRONIC   0.812657  0.884032  0.895050  0.852755      0.860477
# TOBACCO         0.771763  0.836097  0.845067  0.806749      0.816539
# PNEUMONIA      -0.004484 -0.005618 -0.005392 -0.000802     -0.004799
# AGE             0.004422  0.019048  0.022715  0.022820     -0.004964
#
# ...

# %%
sns.heatmap(s.corr(),annot=True,fmt='.1f')
plt.tight_layout()

# %% [markdown]
# 9. What is the distribution of ages among different outcomes (recovered, died)?

# %%
df['DATE_DIED'].value_counts()
# Out:
# 9999-99-99    971633
# 06/07/2020      1000
# 07/07/2020       996
# 13/07/2020       990
# 16/06/2020       979
#                ...
# 24/11/2020         1
# 17/12/2020         1
# 08/12/2020         1
# 16/03/2021         1
# 22/04/2021         1
# Name: DATE_DIED, Length: 401, dtype: int64

# %%
died=df[df['DATE_DIED']!='9999-99-99']

# %%
recover=df[df['DATE_DIED']=='9999-99-99']

# %%
fig,axes=plt.subplots(1,2)
sns.histplot(died['AGE'], bins=20, color='green', alpha=0.7, ax=axes[0])
axes[0].set_title('Age Distribution - Died')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frequency')

sns.histplot(recover['AGE'], bins=20, color='blue', alpha=0.7, ax=axes[1])
axes[1].set_title('Age Distribution - Recovered')
axes[1].set_xlabel('Age')
axes[1].set_ylabel('Frequency')
plt.tight_layout()

# %% [markdown]
# 10. Can we create a bar chart to show the count of patients in each medical unit?

# %%
sns.countplot(x=df["MEDICAL_UNIT"])
# Out:
# <Axes: xlabel='MEDICAL_UNIT', ylabel='count'>

# %% [markdown]
# 11. How does the distribution of ages vary between male and female patients?

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  AGE  \
# 0      2             1   F             1  03/05/2020       97          1   65
# 1      2             1   M             1  03/06/2020       97          1   72
# 2      2             1   M             2  09/06/2020        1          2   55
# 3      2             1   F             1  12/06/2020       97          2   53
# 4      2             1   M             1  21/06/2020       97          2   68
#
#    PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2  ...       2        2             1              2
# 1        97         2  ...       2        2             1              2
# 2        97         1  ...       2        2             2              2
# 3         2         2  ...       2        2             2              2
# 4        97         1  ...       2        2             1              2
#
# ...

# %%
gender_mapping = {1:'F', 2:'M'}

# %%
df['SEX'] = df['SEX'].map(gender_mapping)

# %%
sns.kdeplot(data=df, x='AGE', hue='SEX', fill=True, palette={'M': 'blue', 'F': 'pink'})
# Out:
# <Axes: xlabel='AGE', ylabel='Density'>

# %%
sns.histplot(data=df, x='AGE', hue='SEX', bins=20, multiple='stack', palette={'M': 'blue', 'F': 'pink'})
plt.title('Distribution of Ages by Gender')
# Out:
# Text(0.5, 1.0, 'Distribution of Ages by Gender')

# %% [markdown]
# 12. Can we visualize the percentage of smokers among the patients?

# %%
sns.countplot(data=df, x='TOBACCO',hue='SEX')
# Out:
# <Axes: xlabel='TOBACCO', ylabel='count'>

# %%
percentage_data = (df.groupby(['SEX', 'TOBACCO']).size() / df.groupby('SEX').size() * 100).reset_index(name='Percentage')


sns.barplot(x='TOBACCO', y='Percentage', hue='SEX', data=percentage_data)
plt.title('Percentage of Smokers Among Patients by Gender')
plt.xlabel('Tobacco Use')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# 13. What is the average age of patients with and without diabetes?

# %%
df.head(2)
# Out:
#    USMER  MEDICAL_UNIT SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  AGE  \
# 0      2             1   F             1  03/05/2020       97          1   65
# 1      2             1   M             1  03/06/2020       97          1   72
#
#    PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2  ...       2        2             1              2
# 1        97         2  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
#
# [2 rows x 21 columns]

# %%
df.groupby('DIABETES')['AGE'].mean()
# Out:
# DIABETES
# 1     56.964221
# 2     39.707406
# 98    49.038047
# Name: AGE, dtype: float64

# %% [markdown]
# 14. How does the distribution of ages differ between ICU-admitted and non-ICU-admitted patients?

# %%
sns.histplot(x='AGE',data = df, hue='ICU',bins=20,multiple='stack',palette='pastel')
plt.title('Distribution of Ages by ICU ')
# Out:
# Text(0.5, 1.0, 'Distribution of Ages by ICU ')

# %% [markdown]
# 15. Can we visualize the trend of COVID cases over time (if time information is available)?

# %%
df['DATE_DIED']=pd.to_datetime(df['DATE_DIED'],errors='coerce')
# Out:
# C:\Users\shrid\AppData\Local\Temp\ipykernel_9500\2802845470.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['DATE_DIED']=pd.to_datetime(df['DATE_DIED'],errors='coerce')

# %%
cases = df.groupby('DATE_DIED').size().reset_index(name='CASES')

# %%
cases.head()
# Out:
#    DATE_DIED  CASES
# 0 2020-01-02     13
# 1 2020-01-03     11
# 2 2020-01-04     56
# 3 2020-01-05    555
# 4 2020-01-06    829

# %%
sns.lineplot(x=cases['CASES'],y=df['DATE_DIED'],marker='o')
plt.title('Trend of COVID Cases Over Time')
plt.grid(True)

# %% [markdown]
# 16.Is there a difference in age distribution between pregnant and non-pregnant patients?

# %%
df.head(2)
# Out:
#    USMER  MEDICAL_UNIT SEX  PATIENT_TYPE  DATE_DIED  INTUBED  PNEUMONIA  AGE  \
# 0      2             1   F             1 2020-03-05       97          1   65
# 1      2             1   M             1 2020-03-06       97          1   72
#
#    PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2  ...       2        2             1              2
# 1        97         2  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
#
# [2 rows x 21 columns]

# %%
filtered_df = df[df['PREGNANT'].isin([1, 2])]

# %%
sns.histplot(data=filtered_df, x='AGE', hue='PREGNANT', bins=20, multiple='stack', palette='pastel')
plt.title('Age Distribution Between Pregnant and Non-Pregnant Patients')
# Out:
# Text(0.5, 1.0, 'Age Distribution Between Pregnant and Non-Pregnant Patients')

# %% [markdown]
# 17. How does the distribution of ages vary between different outcomes (recovered, died) for diabetic patients?

# %%
diabetic_df = df[df['DIABETES'] == 1]
recover1 = diabetic_df[diabetic_df['DATE_DIED'] == '9999-99-99']
died1 = diabetic_df[diabetic_df['DATE_DIED'] != '9999-99-99']

# %%
sns.histplot(recover['AGE'], bins=20, color='green', alpha=0.7)
plt.title('Age distribution for Recovered patient with Diabetics')
# Out:
# Text(0.5, 1.0, 'Age distribution for Recovered patient with Diabetics')

# %%
sns.histplot(died['AGE'], bins=20, color='red', alpha=0.7, label='Died')
plt.title('Age distribution for Dead patient with Diabetics')
# Out:
# Text(0.5, 1.0, 'Age distribution for Dead patient with Diabetics')
